# %% [markdown]
# **Installing Libraries**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 665.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.32.1 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# ...

# %% [markdown]
# **Importing Libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# **Search for Target Protein**
#
# Target Search for Cancer

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('cardiac therapy')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references                organism  \
# 0                                                  []            Homo sapiens
# 1   [{'xref_id': 'Q32MK0', 'xref_name': None, 'xre...            Homo sapiens
# 2   [{'xref_id': 'Q8WN72', 'xref_name': None, 'xre...  Canis lupus familiaris
# 3                                                  []            Homo sapiens
# 4                                                  []            Mus musculus
# ..                                                ...                     ...
# 60                                                 []            Homo sapiens
# 61                                                 []            Mus musculus
# 62                                                 []       Rattus norvegicus
# 63                                                 []            Homo sapiens
# 64                                                 []            Homo sapiens
#
# ...

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL4627'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target)

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     action_type activity_comment  activity_id  \
# 0          None             None      7567144
# 1          None             None      7567603
# 2          None             None      7568074
# 3          None             None      7568542
# 4          None             None      7568974
# ..          ...              ...          ...
# 468        None       Not Active     23385097
# 469        None       Not Active     23385564
# 470        None       Not Active     24518773
# 471        None       Not Active     24647879
# 472        None       Not Active     24648574
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []   CHEMBL1908435
# 1                                                   []   CHEMBL1908435
# 2                                                   []   CHEMBL1908435
# 3                                                   []   CHEMBL1908435
# ...

# %%
df.to_csv('cardiac_therapy_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# **Handling missing data**

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-33-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#     action_type activity_comment  activity_id  \
# 0          None             None      7567144
# 1          None             None      7567603
# 2          None             None      7568074
# 3          None             None      7568542
# 4          None             None      7568974
# ..          ...              ...          ...
# 467        None       Not Active     23384351
# 468        None       Not Active     23385097
# 469        None       Not Active     23385564
# 471        None       Not Active     24647879
# 472        None       Not Active     24648574
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []   CHEMBL1908435
# 1                                                   []   CHEMBL1908435
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 414

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     action_type activity_comment  activity_id  \
# 0          None             None      7567144
# 1          None             None      7567603
# 2          None             None      7568074
# 3          None             None      7568542
# 4          None             None      7568974
# ..          ...              ...          ...
# 467        None       Not Active     23384351
# 468        None       Not Active     23385097
# 469        None       Not Active     23385564
# 471        None       Not Active     24647879
# 472        None       Not Active     24648574
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []   CHEMBL1908435
# 1                                                   []   CHEMBL1908435
# 2                                                   []   CHEMBL1908435
# 3                                                   []   CHEMBL1908435
# ...

# %% [markdown]
# **Data pre-processing of the bioactivity data**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL215152  CCN(CCO)CCCOc1ccc2c(Nc3cc(CC(=O)Nc4cccc(F)c4)[...
# 1         CHEMBL105442          O=C(NOCC1CC1)c1ccc(F)c(F)c1Nc1ccc(I)cc1Cl
# 2         CHEMBL180022  CCOc1cc2ncc(C#N)c(Nc3ccc(OCc4ccccn4)c(Cl)c3)c2...
# 3         CHEMBL386051  CSc1cccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3...
# 4        CHEMBL1721885  Cc1[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c(C)c1C(=O)N...
# ..                 ...                                                ...
# 467      CHEMBL4802045  CC[C@@H](Nc1c(C#N)c(-c2ccc(-c3cccc(C)c3F)cc2)n...
# 468      CHEMBL4568735  CO[C@@H](C)c1c(Nc2ccc([C@H](N(C)C(=O)C3CCS(=O)...
# 469      CHEMBL4584981  CO[C@@H](C)c1c(Nc2ccc([C@@H](N(C)C(=O)C3CCS(=O...
# 471      CHEMBL5081774  [2H]C([2H])([2H])C1(C([2H])([2H])[2H])Cn2nc(-c...
# 472      CHEMBL5084426  COc1cnccc1Nc1nc(-c2nn(Cc3c(F)cc(OCCO)cc3F)c3cc...
#
#     standard_value
# 0          10000.0
# 1          10000.0
# ...

# %%
df3.to_csv('cardiac_therapy_2_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('cancer_therapy_2_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL215152  CCN(CCO)CCCOc1ccc2c(Nc3cc(CC(=O)Nc4cccc(F)c4)[...
# 1         CHEMBL105442          O=C(NOCC1CC1)c1ccc(F)c(F)c1Nc1ccc(I)cc1Cl
# 2         CHEMBL180022  CCOc1cc2ncc(C#N)c(Nc3ccc(OCc4ccccn4)c(Cl)c3)c2...
# 3         CHEMBL386051  CSc1cccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3...
# 4        CHEMBL1721885  Cc1[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c(C)c1C(=O)N...
# ..                 ...                                                ...
# 409      CHEMBL4802045  CC[C@@H](Nc1c(C#N)c(-c2ccc(-c3cccc(C)c3F)cc2)n...
# 410      CHEMBL4568735  CO[C@@H](C)c1c(Nc2ccc([C@H](N(C)C(=O)C3CCS(=O)...
# 411      CHEMBL4584981  CO[C@@H](C)c1c(Nc2ccc([C@@H](N(C)C(=O)C3CCS(=O...
# 412      CHEMBL5081774  [2H]C([2H])([2H])C1(C([2H])([2H])[2H])Cn2nc(-c...
# 413      CHEMBL5084426  COc1cnccc1Nc1nc(-c2nn(Cc3c(F)cc(OCCO)cc3F)c3cc...
#
#      standard_value     class
# 0          10000.00  inactive
# ...

# %%
df5.to_csv('cardiac_therapy_3_bioactivity_data_curated.csv', index=False)

# %%
! zip cardiac_therapy.zip *.csv
# Out:
#   adding: cancer_01_bioactivity_data_raw.csv (deflated 63%)
#   adding: cancer_therapy_2_bioactivity_data_preprocessed.csv (deflated 71%)
#   adding: cardiac_therapy_3_bioactivity_data_curated.csv (deflated 73%)
#   adding: cardiac_therapy_bioactivity_data_raw.csv (deflated 91%)

# %%
! ls -l
# Out:
# total 424
# -rw-r--r-- 1 root root   1631 Jan 14 07:04 cancer_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  34000 Jan 14 07:14 cancer_therapy_2_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  37406 Jan 14 07:16 cardiac_therapy_3_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 297323 Jan 14 07:12 cardiac_therapy_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  48943 Jan 14 07:16 cardiac_therapy.zip
# drwxr-xr-x 1 root root   4096 Jan 11 17:02 sample_data
